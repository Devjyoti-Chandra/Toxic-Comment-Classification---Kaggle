# %%
import numpy as np # linear algebra
import pandas as pd 

from keras.models import Model
from keras.layers import Dense, Embedding, Input
from keras.layers import LSTM, Bidirectional, GlobalMaxPool1D, Dropout
from keras.preprocessing import text, sequence
from keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
max_features = 20000
maxlen = 100

# %%
train = pd.read_csv("data/train_cleaned.csv")
test = pd.read_csv("data/test_cleaned.csv")

# %%
list_sentences_train = train["comment_text"].fillna("unk").values
list_classes = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]
y = train[list_classes].values
list_sentences_test = test["comment_text"].fillna("unk").values

# %%
list_sentences_train = train["comment_text"].fillna("unk").values
list_classes = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]
y = train[list_classes].values
list_sentences_test = test["comment_text"].fillna("unk").values

# %%
tokenizer = text.Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(list(list_sentences_train))
list_tokenized_train = tokenizer.texts_to_sequences(list_sentences_train)
list_tokenized_test = tokenizer.texts_to_sequences(list_sentences_test)
X_t = sequence.pad_sequences(list_tokenized_train, maxlen=maxlen)
X_te = sequence.pad_sequences(list_tokenized_test, maxlen=maxlen)

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('nonsens', 960),
#              ('kiss', 130),
#              ('off', 3767),
#              ('geek', 68),
#              ('what', 20812),
#              ('i', 144284),
#              ('said', 4672),
#              ('is', 108822),
#              ('true', 2064),
#              ('will', 23384),
#              ('have', 54088),
#              ('your', 38433),
#              ('account', 2949),
#              ('termin', 110),
#              ('plea', 18053),
#              ('do', 40401),
#              ('not', 87629),
#              ('vandal', 6528),
#              ('page', 34760),
#              ('a', 176681),
#              ('you', 132262),
#              ('did', 12170),
#              ('with', 36162),
#              ('this', 58665),
#              ('edit', 25144),
#              ('to', 178539),
#              ('w', 876),
#              ('s', 3955),
#              ('merwin', 1),
#              ('if', 35353),
#              ('continu', 3951),
#              ('so', 21883),
#              ('be', 58990),
#              ('block', 10247),
#              ('from', 24991),
#              ('point', 6846),
#              ('of', 135457),
#              ('interest', 4249),
#              ('remov', 9394),
#              ('the', 298773),
#              ('section', 6887),
#              ('ad', 7200),
#              ('becaus', 11634),
#              ('it', 96140),
#              ('seem', 6325),
#              ('kind', 2172),
#              ('spammi', 18),
#              ('know', 12360),
#              ('probabl', 2694),
#              ('mean', 5504),
#              ('disobey', 8),
#              ('rule', 3407),
#              ('but', 30571),
#              ('general', 3036),
#              ('tend', 381),
#              ('rather', 2822),
#              ('touristi', 1),
#              ('and', 134726),
#              ('quit', 2406),
#              ('irrelev', 675),
#              ('an', 26702),
#              ('area', 1424),
#              ('cultur', 1269),
#              ('that', 97717),
#              ('just', 16613),
#              ('my', 27361),
#              ('opinion', 3313),
#              ('though', 3085),
#              ('want', 9041),
#              ('repli', 1568),
#              ('put', 4457),
#              ('here', 13543),
#              ('add', 5216),
#              ('talkback', 96),
#              ('jamiegraham08', 1),
#              ('on', 54143),
#              ('talkpag', 353),
#              ('ask', 5775),
#              ('some', 13382),
#              ('his', 12351),
#              ('nation', 2386),
#              ('racial', 251),
#              ('offenc', 124),
#              ('wow', 472),
#              ('wa', 34034),
#              ('awar', 1111),
#              ('me', 22622),
#              ('ha', 19257),
#              ('shown', 580),
#              ('support', 3686),
#              ('toward', 897),
#              ('communiti', 1685),
#              ('thanku', 1),
#              ('for', 62110),
#              ('reader', 1301),
#              ('go', 10700),
#              ('by', 24947),
#              ('say', 10701),
#              ('ether', 15),
#              ('vocal', 105),
#              ('style', 2881),
#              ('dark', 318),
#              ('lyric', 142),
#              ('content', 4917),
#              ('cite', 2754),
#              ('sourc', 14376),
#              ('in', 87695),
#              ('extern', 1024),
#              ('link', 9092),
#              ('are', 51065),
#              ('those', 5305),
#              ('thing', 6717),
#              ('feel', 4270),
#              ('unreli', 247),
#              ('or', 32497),
#              ('repres', 951),
#              ('they', 17603),
#              ('correct', 3319),
#              ('rewrit', 407),
#              ('delet', 16602),
#              ('fri', 72),
#              ('chicken', 246),
#              ('dat', 47),
#              ('sum', 157),
#              ('whi', 10770),
#              ('can', 20940),
#              ('english', 2886),
#              ('exampl', 3118),
#              ('player', 635),
#              ('other', 16484),
#              ('peopl', 11280),
#              ('like', 18604),
#              ('guy', 2248),
#              ('fawk', 17),
#              ('im', 1002),
#              ('resid', 325),
#              ('bridgwat', 3),
#              ('carniv', 14),
#              ('everi', 2520),
#              ('year', 4772),
#              ('wuit', 1),
#              ('dedic', 242),
#              ('town', 536),
#              ('enjoy', 1154),
#              ('alot', 178),
#              ('about', 22562),
#              ('howev', 3873),
#              ('think', 13124),
#              ('wrong', 3298),
#              ('although', 1504),
#              ('we', 15318),
#              ('rebel', 114),
#              ('carnvial', 1),
#              ('celebr', 278),
#              ('get', 10782),
#              ('caught', 212),
#              ('therfor', 6),
#              ('prevent', 710),
#              ('would', 21803),
#              ('somebodi', 549),
#              ('murder', 610),
#              ('out', 10528),
#              ('majisti', 1),
#              ('far', 2506),
#              ('nicknam', 158),
#              ('articl', 44642),
#              ('embarrass', 104),
#              ('where', 6031),
#              ('human', 1307),
#              ('fish', 1165),
#              ('golden', 140),
#              ('fli', 282),
#              ('american', 2298),
#              ('super', 252),
#              ('among', 716),
#              ('wiki', 5268),
#              ('should', 15128),
#              ('asham', 107),
#              ('mess', 574),
#              ('anonym', 785),
#              ('there', 21145),
#              ('sign', 2044),
#              ('post', 5153),
#              ('woodland', 8),
#              ('meadow', 9),
#              ('good', 7814),
#              ('hear', 751),
#              ('well', 7586),
#              ('finish', 472),
#              ('bit', 2195),
#              ('had', 7692),
#              ('chanc', 731),
#              ('through', 2403),
#              ('all', 18743),
#              ('tag', 5353),
#              ('referenc', 748),
#              ('yet', 2253),
#              ('sinc', 5192),
#              ('work', 8446),
#              ('call', 5199),
#              ('am', 21288),
#              ('extrem', 824),
#              ('confid', 173),
#              ('scientif', 798),
#              ('factual', 693),
#              ('basi', 579),
#              ('everyth', 1316),
#              ('state', 6409),
#              ('pretti', 1311),
#              ('much', 5728),
#              ('made', 5730),
#              ('book', 3769),
#              ('particl', 87),
#              ('imag', 9121),
#              ('velocimetri', 2),
#              ('practic', 908),
#              ('guid', 637),
#              ('raffel', 1),
#              ('willert', 1),
#              ('wereley', 1),
#              ('kompenhan', 1),
#              ('someon', 4867),
#              ('also', 12369),
#              ('sure', 4227),
#              ('how', 11363),
#              ('exact', 1627),
#              ('found', 2868),
#              ('numer', 543),
#              ('journal', 550),
#              ('databas', 176),
#              ('etc', 2531),
#              ('conveni', 149),
#              ('place', 5809),
#              ('one', 18612),
#              ('onli', 10604),
#              ('unsur', 71),
#              ('no', 17971),
#              ('experi', 1778),
#              ('molecular', 33),
#              ('simpli', 2434),
#              ('keep', 3939),
#              ('techniqu', 170),
#              ('defect', 42),
#              ('summari', 1896),
#              ('blunt', 68),
#              ('descript', 1243),
#              ('now', 8835),
#              ('too', 4712),
#              ('problem', 4189),
#              ('fact', 6545),
#              ('develop', 1191),
#              ('97ish', 1),
#              ('widespread', 96),
#              ('use', 21394),
#              ('were', 9689),
#              ('accur', 1026),
#              ('everyon', 1371),
#              ('met', 321),
#              ('heard', 809),
#              ('person', 8938),
#              ('which', 15308),
#              ('big', 1693),
#              ('flaw', 186),
#              ('find', 6132),
#              ('guest', 123),
#              ('el', 2795),
#              ('discus', 8824),
#              ('befor', 5128),
#              ('critic', 2004),
#              ('inform', 8427),
#              ('posit', 2168),
#              ('complet', 2357),
#              ('defend', 702),
#              ('open', 1746),
#              ('solid', 613),
#              ('argument', 2027),
#              ('wo', 1232),
#              ('pighead', 5),
#              ('anyon', 3021),
#              ('knowledg', 1262),
#              ('tomograph', 1),
#              ('piv', 1),
#              ('expand', 722),
#              ('volumetr', 2),
#              ('analysi', 377),
#              ('new', 6359),
#              ('noth', 3141),
#              ('take', 6623),
#              ('talk', 24415),
#              ('user', 11233),
#              ('weight', 516),
#              ('into', 5330),
#              ('detail', 1744),
#              ('who', 13479),
#              ('play', 1899),
#              ('chess', 91),
#              ('their', 8738),
#              ('ethnic', 794),
#              ('motiv', 500),
#              ('write', 4130),
#              ('them', 8891),
#              ('ahead', 567),
#              ('see', 13818),
#              ('surviv', 261),
#              ('notabl', 4093),
#              ('uh', 104),
#              ('oh', 2565),
#              ('bluff', 12),
#              ('intimid', 103),
#              ('number', 2871),
#              ('posse', 141),
#              ('7000', 8),
#              ('painter', 23),
#              ('teacher', 245),
#              ('bliss', 19),
#              ('ignor', 1778),
#              ('most', 5993),
#              ('comput', 947),
#              ('best', 3481),
#              ('way', 7251),
#              ('upload', 2124),
#              ('common', 2094),
#              ('caption', 239),
#              ('under', 4370),
#              ('proper', 1560),
#              ('head', 1424),
#              ('suggest', 3882),
#              ('more', 14149),
#              ('experienc', 366),
#              ('art', 671),
#              ('editor', 7065),
#              ('than', 8357),
#              ('wetman', 7),
#              ('caravaggisti', 2),
#              ('ewulp', 1),
#              ('celithimus', 1),
#              ('adviceyou', 1),
#              ('contribut', 5149),
#              ('throughout', 361),
#              ('histori', 4359),
#              ('artist', 605),
#              ('entri', 1647),
#              ('mayb', 2222),
#              ('option', 453),
#              ('pictur', 2236),
#              ('even', 8277),
#              ('when', 10015),
#              ('lot', 2600),
#              ('actual', 4597),
#              ('hate', 2218),
#              ('onc', 2063),
#              ('up', 10615),
#              ('either', 2523),
#              ('own', 4890),
#              ('retic', 7),
#              ('undo', 462),
#              ('done', 3742),
#              ('respect', 1538),
#              ('visual', 142),
#              ('ani', 15433),
#              ('help', 8231),
#              ('glad', 515),
#              ('clear', 4439),
#              ('great', 2962),
#              ('collect', 559),
#              ('photo', 1255),
#              ('veri', 7359),
#              ('generous', 45),
#              ('regard', 3608),
#              ('contact', 1276),
#              ('live', 2878),
#              ('descend', 223),
#              ('adolf', 56),
#              ('hitler', 717),
#              ('order', 1730),
#              ('whether', 2090),
#              ('give', 4329),
#              ('him', 4812),
#              ('raw', 98),
#              ('deal', 1380),
#              ('absolut', 905),
#              ('reliabl', 3081),
#              ('die', 2569),
#              ('truth', 1372),
#              ('negoti', 108),
#              ('differ', 4139),
#              ('issu', 4825),
#              ('andemu', 25),
#              ('may', 9550),
#              ('2008', 1212),
#              ('utc', 4059),
#              ('heart', 354),
#              ('been', 15113),
#              ('request', 4110),
#              ('speedili', 562),
#              ('wikipedia', 29423),
#              ('appear', 3172),
#              ('real', 2358),
#              ('organ', 1330),
#              ('band', 1488),
#              ('club', 730),
#              ('compani', 1652),
#              ('web', 1411),
#              ('doe', 11076),
#              ('indic', 1596),
#              ('subject', 4140),
#              ('includ', 5406),
#              ('encyclopedia', 2443),
#              ('criterion', 2455),
#              ('speedi', 2939),
#              ('import', 3063),
#              ('signific', 1239),
#              ('at', 23663),
#              ('time', 11700),
#              ('guidelin', 2624),
#              ('accept', 2610),
#              ('first', 6829),
#              ('creat', 5350),
#              ('then', 9893),
#              ('read', 6668),
#              ('assert', 930),
#              ('contest', 892),
#              ('top', 2515),
#              ('below', 1363),
#              ('exist', 2967),
#              ('db', 400),
#              ('coupl', 1015),
#              ('note', 5126),
#              ('explain', 3137),
#              ('meet', 1408),
#              ('without', 4326),
#              ('delay', 346),
#              ('yourself', 3852),
#              ('hesit', 523),
#              ('confirm', 1139),
#              ('specif', 2323),
#              ('type', 1727),
#              ('check', 3492),
#              ('our', 4251),
#              ('biographi', 1008),
#              ('site', 3494),
#              ('free', 3976),
#              ('leav', 3285),
#              ('question', 7281),
#              ('20', 1374),
#              ('03', 407),
#              ('18', 928),
#              ('while', 3608),
#              ('agre', 3638),
#              ('fa', 339),
#              ('materi', 2612),
#              ('must', 3050),
#              ('lead', 1754),
#              ('repetit', 84),
#              ('splc', 41),
#              ('show', 4304),
#              ('least', 2453),
#              ('amend', 263),
#              ('polit', 2072),
#              ('cesspool', 7),
#              ('host', 297),
#              ('former', 663),
#              ('member', 1736),
#              ('ku', 25),
#              ('klux', 14),
#              ('klan', 29),
#              ('david', 611),
#              ('duke', 195),
#              ('interview', 479),
#              ('major', 1894),
#              ('radio', 316),
#              ('televis', 276),
#              ('program', 716),
#              ('countri', 2203),
#              ('perhap', 2121),
#              ('furthermor', 402),
#              ('1970', 87),
#              ('near', 830),
#              ('three', 1993),
#              ('decad', 251),
#              ('went', 959),
#              ('air', 648),
#              ('wolf', 88),
#              ('blitzer', 15),
#              ('he', 17510),
#              ('alreadi', 3192),
#              ('mani', 5760),
#              ('flagrant', 22),
#              ('bias', 1933),
#              ('right', 6328),
#              ('frequent', 430),
#              ('current', 3273),
#              ('mislead', 493),
#              ('regardless', 464),
#              ('ideolog', 240),
#              ('name', 9278),
#              ('stonemason', 1),
#              ('turkish', 336),
#              ('citizen', 349),
#              ('receiv', 919),
#              ('award', 803),
#              ('due', 1309),
#              ('root', 254),
#              ('entitl', 247),
#              ('need', 9522),
#              ('mention', 4442),
#              ('bundesliga', 7),
#              ('remark', 534),
#              ('end', 2230),
#              ('disagr', 270),
#              ('censorship', 374),
#              ('qualiti', 837),
#              ('addit', 2108),
#              ('topic', 2293),
#              ('toler', 265),
#              ('jayjg', 62),
#              ('childish', 161),
#              ('immatur', 95),
#              ('epithet', 33),
#              ('spew', 41),
#              ('excus', 454),
#              ('unaccept', 271),
#              ('transpar', 105),
#              ('lokison', 1),
#              ('case', 4608),
#              ('war', 3637),
#              ('last', 3153),
#              ('forev', 315),
#              ('tit', 60),
#              ('tat', 35),
#              ('long', 2925),
#              ('never', 3778),
#              ('sulli', 12),
#              ('reput', 459),
#              ('revert', 6261),
#              ('falsehood', 54),
#              ('encourag', 522),
#              ('abus', 1471),
#              ('vilifi', 13),
#              ('touch', 428),
#              ('come', 4423),
#              ('down', 2307),
#              ('let', 4199),
#              ('movement', 700),
#              ('u', 7238),
#              ('domin', 231),
#              ('territori', 398),
#              ('huh', 169),
#              ('vicious', 63),
#              ('sever', 2123),
#              ('innoc', 276),
#              ('24', 1353),
#              ('255', 87),
#              ('11', 1279),
#              ('149', 114),
#              ('georg', 547),
#              ('washington', 305),
#              ('chang', 7447),
#              ('constitut', 805),
#              ('word', 5133),
#              ('direct', 2018),
#              ('unabl', 278),
#              ('provid', 3491),
#              ('onlin', 773),
#              ('refer', 7842),
#              ('multipl', 916),
#              ('print', 454),
#              ('medium', 2304),
#              ('privat', 496),
#              ('librari', 429),
#              ('alitalia', 2),
#              ('rom', 61),
#              ('allianc', 102),
#              ('piss', 304),
#              ('poor', 874),
#              ('custom', 211),
#              ('servic', 863),
#              ('sentiment', 106),
#              ('nummer', 1),
#              ('flyertalk', 1),
#              ('anoth', 4006),
#              ('afd', 949),
#              ('stat', 181),
#              ('hope', 4247),
#              ('mind', 1880),
#              ('these', 6667),
#              ('anyth', 3489),
#              ('refin', 52),
#              ('tool', 596),
#              ('thought', 2816),
#              ('certain', 2431),
#              ('deathland', 1),
#              ('close', 1609),
#              ('merg', 1160),
#              ('presum', 299),
#              ('pull', 282),
#              ('statement', 2629),
#              ('realli', 5410),
#              ('n', 1075),
#              ('consensus', 2503),
#              ('requir', 1746),
#              ('terminolog', 155),
#              ('result', 1814),
#              ('could', 7631),
#              ('outcom', 170),
#              ('such', 6939),
#              ('huge', 581),
#              ('joint', 98),
#              ('nomin', 1698),
#              ('serenc', 5),
#              ('ah', 390),
#              ('got', 2564),
#              ('random', 554),
#              ('presid', 630),
#              ('usa', 168),
#              ('known', 1699),
#              ('fire', 817),
#              ('contrib', 1735),
#              ('move', 3241),
#              ('tedious', 46),
#              ('survey', 242),
#              ('helmet', 43),
#              ('cycl', 136),
#              ('particip', 961),
#              ('after', 5219),
#              ('introduct', 604),
#              ('law', 1503),
#              ('footnot', 325),
#              ('whole', 1755),
#              ('becom', 1657),
#              ('unread', 43),
#              ('structur', 506),
#              ('duplic', 268),
#              ('anniehal', 1),
#              ('separ', 1025),
#              ('capit', 523),
#              ('terror', 403),
#              ('conduct', 463),
#              ('against', 3238),
#              ('jurisdict', 83),
#              ('legitim', 511),
#              ('matter', 2680),
#              ('polici', 4940),
#              ('holocaust', 252),
#              ('et', 251),
#              ('al', 640),
#              ('nazi', 772),
#              ('germani', 407),
#              ('cannot', 4881),
#              ('communism', 194),
#              ('pov', 2197),
#              ('singl', 1516),
#              ('clan', 117),
#              ('guild', 61),
#              ('star', 664),
#              ('battlefront', 2),
#              ('ii', 390),
#              ('ps2', 10),
#              ('grace', 95),
#              ('slick', 17),
#              ('non', 2685),
#              ('ungrac', 4),
#              ('dick', 1091),
#              ('86', 408),
#              ('131', 102),
#              ('154', 79),
#              ('225', 64),
#              ('dure', 1359),
#              ('decemb', 642),
#              ('2', 4359),
#              ('2006', 1349),
#              ('thank', 14481),
#              ('test', 1859),
#              ('sandbox', 1294),
#              ('look', 8401),
#              ('welcom', 4053),
#              ('learn', 1874),
#              ('612', 6),
#              ('er', 165),
#              ('discrep', 51),
#              ('inaccuraci', 84),
#              ('fine', 1080),
#              ('track', 500),
#              ('abl', 1441),
#              ('verifi', 1811),
#              ('third', 1012),
#              ('parti', 1717),
#              ('trivia', 201),
#              ('appli', 1189),
#              ('smackdown', 48),
#              ('qatar', 19),
#              ('wasn', 30),
#              ('t', 3024),
#              ('khalifa', 14),
#              ('famili', 1204),
#              ('nowher', 209),
#              ('nearbi', 58),
#              ('intent', 995),
#              ('138', 118),
#              ('162', 135),
#              ('128', 152),
#              ('53', 199),
#              ('stupid', 1219),
#              ('soon', 1078),
#              ('saw', 991),
#              ('phrase', 740),
#              ('metal', 514),
#              ('begin', 894),
#              ('assum', 1407),
#              ('misread', 58),
#              ('inde', 1045),
#              ('chemistri', 94),
#              ('soviet', 433),
#              ('educ', 821),
#              ('system', 1864),
#              ('refut', 195),
#              ('amount', 692),
#              ('typo', 147),
#              ('respond', 1239),
#              ('ban', 2455),
#              ('side', 1651),
#              ('bullshit', 1108),
#              ('admin', 3428),
#              ('islamist', 61),
#              ('won', 383),
#              ('better', 3722),
#              ('class', 1214),
#              ('again', 5948),
#              ('controversi', 1272),
#              ('hi', 4327),
#              ('cyclist', 11),
#              ('robbi', 24),
#              ('mcewen', 2),
#              ('complain', 483),
#              ('via', 492),
#              ('twitter', 125),
#              ('alongsid', 75),
#              ('bradley', 37),
#              ('wiggin', 3),
#              ('stuart', 43),
#              ('o', 1114),
#              ('gradi', 4),
#              ('suppli', 229),
#              ('contain', 1082),
#              ('both', 3527),
#              ('back', 4994),
#              ('ref', 546),
#              ('took', 1221),
#              ('few', 2898),
#              ('second', 2229),
#              ('hasti', 39),
#              ('porn', 136),
#              ('email', 1500),
#              ('wonder', 1318),
#              ('sent', 620),
#              ('dont', 1489),
#              ('apprici', 9),
#              ('behavior', 812),
#              ('report', 2933),
#              ('isp', 80),
#              ('dfw', 5),
#              ('fio', 3),
#              ('verizon', 35),
#              ('insan', 134),
#              ('offens', 621),
#              ('send', 614),
#              ('goodby', 115),
#              ('offend', 444),
#              ('accus', 1777),
#              ('address', 2625),
#              ('suspici', 106),
#              ('relev', 1737),
#              ('proof', 986),
#              ('forward', 608),
#              ('administr', 2524),
#              ('funni', 538),
#              ('make', 12538),
#              ('view', 3674),
#              ('internet', 995),
#              ('curious', 328),
#              ('decid', 1831),
#              ('someth', 4477),
#              ('gay', 1520),
#              ('sound', 1295),
#              ('tri', 6944),
#              ('myself', 1606),
#              ('unblock', 1528),
#              ('care', 2553),
#              ('72', 310),
#              ('hour', 1298),
#              ('prove', 1289),
#              ('claim', 4462),
#              ('littl', 3054),
#              ('kid', 594),
#              ('petti', 138),
#              ('bureaucrat', 108),
#              ('sen', 1696),
#              ('uphold', 68),
#              ('attack', 3742),
#              ('substanc', 142),
#              ('taken', 1438),
#              ('grain', 33),
#              ('salt', 182),
#              ('stop', 4740),
#              ('goguryeo', 5),
#              ('approv', 390),
#              ('chine', 541),
#              ('japanes', 540),
#              ('troll', 916),
#              ('korsentri', 11),
#              ('tom', 232),
#              ('chilton', 2),
#              ('game', 2016),
#              ('rm', 114),
#              ('rout', 247),
#              ('improv', 2138),
#              ('userpag', 404),
#              ('green', 393),
#              ('light', 794),
#              ('proxi', 205),
#              ('server', 241),
#              ('ai', 189),
#              ('broke', 163),
#              ('fix', 1593),
#              ('sweep', 142),
#              ('rajiv', 4),
#              ('malhotra', 2),
#              ('polemicist', 4),
#              ('disregard', 150),
#              ('basic', 1171),
#              ('present', 2055),
#              ('incorrect', 865),
#              ('aim', 315),
#              ('neutral', 1977),
#              ('scholar', 712),
#              ('overview', 172),
#              ('understand', 3868),
#              ('india', 838),
#              ('ampl', 46),
#              ('room', 310),
#              ('within', 1374),
#              ('agenda', 486),
#              ('subvers', 20),
#              ('activ', 1257),
#              ('control', 1054),
#              ('board', 608),
#              ('author', 2085),
#              ('unit', 1701),
#              ('g', 1166),
#              ('p', 1627),
#              ('1966', 45),
#              ('213', 100),
#              ('122', 132),
#              ('175', 69),
#              ('236', 62),
#              ('drumk', 1),
#              ('28', 587),
#              ('juli', 892),
#              ('2011', 712),
#              ('http', 4464),
#              ('en', 1762),
#              ('org', 2178),
#              ('israel', 691),
#              ('conflict', 1240),
#              ('peac', 413),
#              ('treati', 133),
#              ('sabra', 4),
#              ('shatila', 4),
#              ('camp', 228),
#              ('massacr', 264),
#              ('broken', 293),
#              ('obsolet', 45),
#              ('strang', 316),
#              ('livelikemus', 5),
#              ('recur', 51),
#              ('charact', 1282),
#              ('prior', 479),
#              ('cast', 475),
#              ('eileen', 4),
#              ('davidson', 25),
#              ('previous', 1453),
#              ('her', 4093),
#              ('kristian', 2),
#              ('alfonso', 14),
#              ('galen', 12),
#              ('gere', 4),
#              ('actor', 285),
#              ('portray', 164),
#              ('confus', 1261),
#              ('date', 2467),
#              ('fun', 609),
#              ('racist', 597),
#              ('respons', 1965),
#              ('lie', 1296),
#              ('unnecessari', 279),
#              ('hello', 2506),
#              ('consid', 4572),
#              ('sophi', 26),
#              ('hunter', 98),
#              ('she', 3711),
#              ('model', 479),
#              ('whose', 482),
#              ('pivot', 16),
#              ('profil', 318),
#              ('nor', 1278),
#              ('bodi', 721),
#              ('infobox', 731),
#              ('still', 4836),
#              ('insert', 916),
#              ('sole', 293),
#              ('represent', 154),
#              ('ration', 200),
#              ('8', 1297),
#              ('februari', 569),
#              ('2007', 1207),
#              ('yes', 2489),
#              ('tangenti', 48),
#              ('anyway', 1763),
#              ('follow', 3719),
#              ('mooni', 3),
#              ('moon', 167),
#              ('oppos', 917),
#              ('evolut', 347),
#              ('opposit', 503),
#              ('pseudosci', 88),
#              ('reject', 433),
#              ('henc', 413),
#              ('reason', 6074),
#              ('scientist', 404),
#              ('debat', 1118),
#              ('merit', 360),
#              ('idea', 2436),
#              ('strawman', 31),
#              ('06', 464),
#              ('55', 401),
#              ('unconstruct', 213),
#              ('colin', 32),
#              ('xx', 44),
#              ('wrestl', 161),
#              ('relat', 2945),
#              ('fingerpok', 1),
#              ('doom', 109),
#              ('99', 405),
#              ('158', 65),
#              ('249', 71),
#              ('195', 152),
#              ('bangladeshi', 21),
#              ('pornstar', 4),
#              ('jazmin', 3),
#              ('worshipthisbitch3', 1),
#              ('jpg', 1732),
#              ('cover', 1311),
#              ('dvd', 158),
#              ('sell', 275),
#              ('updat', 1151),
#              ('nyscholar', 13),
#              ('26', 553),
#              ('archiv', 1343),
#              ('mardavich', 3),
#              ('wish', 1889),
#              ('tactic', 230),
#              ('level', 1084),
#              ('incivil', 180),
#              ('action', 1878),
#              ('fals', 1275),
#              ('irrit', 94),
#              ('disgenuin', 1),
#              ('m', 1836),
#              ('allow', 2088),
#              ('warn', 2619),
#              ('whenev', 227),
#              ('final', 1400),
#              ('involv', 2048),
#              ('minor', 1190),
#              ('disput', 1907),
#              ('instead', 2145),
#              ('askign', 1),
#              ('sort', 1367),
#              ('hould', 12),
#              ('late', 625),
#              ('gonna', 412),
#              ('burn', 268),
#              ('felt', 395),
#              ('grandstand', 7),
#              ('appreci', 1707),
#              ('examin', 265),
#              ('warnign', 1),
#              ('appropri', 1665),
#              ('renomin', 24),
#              ('jan', 242),
#              ('13', 930),
#              ('imo', 201),
#              ('recreat', 185),
#              ('fail', 1246),
#              ('establish', 955),
#              ('origin', 3811),
#              ('research', 2502),
#              ('night', 545),
#              ('crime', 579),
#              ('museum', 180),
#              ...])

# %%
def get_model():
    embed_size = 128
    inp = Input(shape=(maxlen, ))
    x = Embedding(max_features, embed_size)(inp)
    x = Bidirectional(LSTM(100, return_sequences=True))(x)
    x = GlobalMaxPool1D()(x)
    x = Dropout(0.3)(x)
    x = Dense(50, activation="relu")(x)
    x = Dropout(0.1)(x)
    x = Dense(6, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

    return model

# %%
model = get_model()
batch_size = 32
epochs = 3

# %%
file_path="weights_base.best.hdf5"
checkpoint = ModelCheckpoint(file_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

early = EarlyStopping(monitor="val_loss", mode="min", patience=20)

# %%
callbacks_list = [checkpoint, early] #early
model.fit(X_t, y, batch_size=batch_size, epochs=epochs, validation_split=0.1, callbacks=callbacks_list)
# Out:
# Train on 86265 samples, validate on 9586 samples
# Epoch 1/3
# 86240/86265 [============================>.] - ETA: 0s - loss: 0.0687 - acc: 0.9782Epoch 00000: val_loss improved from inf to 0.05175, saving model to weights_base.best.hdf5
# 86265/86265 [==============================] - 886s - loss: 0.0687 - acc: 0.9782 - val_loss: 0.0517 - val_acc: 0.9812
# Epoch 2/3
# 86240/86265 [============================>.] - ETA: 0s - loss: 0.0468 - acc: 0.9825Epoch 00001: val_loss improved from 0.05175 to 0.05137, saving model to weights_base.best.hdf5
# 86265/86265 [==============================] - 831s - loss: 0.0468 - acc: 0.9825 - val_loss: 0.0514 - val_acc: 0.9819
# Epoch 3/3
# 86240/86265 [============================>.] - ETA: 0s - loss: 0.0410 - acc: 0.9843Epoch 00002: val_loss did not improve
# 86265/86265 [==============================] - 829s - loss: 0.0410 - acc: 0.9843 - val_loss: 0.0550 - val_acc: 0.9820

# %%
model.load_weights(file_path)

y_test = model.predict(X_te)

# %%
sample_submission = pd.read_csv("data/sample_submission.csv")

sample_submission[list_classes] = y_test



sample_submission.to_csv("baseline1.csv", index=False)
